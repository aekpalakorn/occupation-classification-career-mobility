# %% [markdown]
# # Multilevel Bayesian Sensitivity Analysis of Upward Career Mobility
#
# This notebook conducts a series of multilevel (mixed-effects) Bayesian logistic regression analyses to evaluate the robustness of the population-averaged estimates obtained in the main regression analysis. By introducing random effects for different grouping structures (e.g., occupation, industry, firm size), this analysis tests whether the key fixed effects in Models 1–4 remain stable after accounting for hierarchical variation.
#
# __Important Note For Reproducibility__
#
# * This data analysis code was developed using a proprietary, licensed commercial dataset (Lightcast data). The raw data files are NOT included in this repository and cannot be publicly shared.
# * The file names for the career trajectory data used in the code are placeholders. To run this notebook, users must substitute them with their own compatible raw data files.
#
#
# ## Overview
#
# The notebook uses Binomial Bayesian Generalized Linear Mixed Models (GLMM) with variational Bayes inference to efficiently fit models on a large dataset of job transitions. It systematically introduces random effects for different organizational and contextual units to:
#
# 1. Assess the stability of fixed-effect estimates (e.g., gender, race, job change type indicators) under hierarchical modeling.
# 2. Examine variance components across occupational, industrial, firm-size, state, and cohort groups.
# 3. Explore whether interaction effects (gender × job change type, race × job change type) remain credible when accounting for multi-level structures.
# 4. Conduct gender-stratified multilevel analyses to probe heterogeneity.
#
# This serves as a robustness check for the main population-averaged GLM results.
#
# ## Dataset
#
# The analysis uses the same LightCast (LC) dataset as the main analysis notebook:
#
# * Population: 229K workers during their first 5 career years.
# * Structure: Each row represents a job-to-job transition pair, with information on demographic attributes, job characteristics, and economic context.
# * Random-effect grouping variables:
#
#   * Occupation (`onet_major_x`)
#   * Industry (`nacis6_major_x`)
#   * State (`state_x`)
#   * Career entry cohort (`job_start_year_x`)
#   * Firm size group (bucketed by observed job transitions per firm)
#
# The firm grouping variable collapses extremely sparse employers into meaningful size categories to improve model stability.
#
# ## Data Table Description:
#
# | Column                                         | Description                                                               |
# | ---------------------------------------------- | ------------------------------------------------------------------------- |
# | `max_edu_name`                                 | Highest degree attained within the first 5-year timeframe                 |
# | `onet_major_x`                                 | Major SOC code (2-digit) of first job                                     |
# | `naics6_major_x`                               | 2-digit NAICS sector of first job                                         |
# | `company_x`                                    | First employer company name                                               |
# | `state_x`                                      | First job state                                                           |
# | `job_start_year_x`                             | Year of first job start                                                   |
# | `num_job_changes`                              | Number of job changes in the 5-year window (top-coded at 95th percentile) |
# | `gender`                                       | Gender (1 = Male, 2 = Female)                                             |
# | `race`                                         | Race (1 = White, 2 = Black, 3 = Asian, 4 = Hispanic)                      |
# | `generation`                                   | Estimated social generation cohort                                        |
# | `state_gdp_decile_x`                           | Decile of state GDP in first job year                                     |
# | `annual_state_wage_x`                          | Occupational wage for the first job (state × 6-digit occupation × year)   |
# | `log_wage_x`                                   | Log-transformed first job wage                                            |
# | `move_1_1`, `move_1_2`, `move_2_1`, `move_2_2` | Job change type indicators for Type-1, Type-2, Type-3, respectively       |
# | `up_move`                                      | Upward mobility indicator: last job wage ≥ 5% above first job wage        |
# | `firm_obs_group_x`                             | Firm size group of first job: Mega, Large, Medium, Sparse                 |
#
#
# ## Methodology
#
# ### Model Specification
#
# Models are estimated using:
#
# * BinomialBayesMixedGLM (`statsmodels.genmod.bayes_mixed_glm`)
# * Fixed effects: Same specification as Models 1–4 in the main analysis, including gender, race, early career mobility types, education, wage, and regional economic controls.
# * Random effects: Introduced incrementally across models to assess their impact on fixed-effect estimates.
# * Continuous covariates are standardized (z-scores) prior to model fitting to improve convergence.
#
# ### Estimation
#
# * Variational Bayes (`fit_vb`) is used for computational efficiency.
# * Posterior means and standard deviations are extracted for both fixed and random effects.
# * 95% credibility intervals are constructed using ±1.96 posterior SDs.
# * Fixed-effect results are converted to odds ratios (OR) for interpretability.
# * Random-effect variances are transformed from log(τ) to τ scale to assess the degree of heterogeneity across groups.
#
# ## Sensitivity Analyses
#
# The notebook fits the following models:
#
# ### Single Random Effect Models (M1A–M1E)
#
# Introduce one grouping structure at a time:
#
# * M1A: Occupation-level random effects
# * M1B: Industry-level random effects
# * M1C: State-level random effects
# * M1D: Career-entry cohort random effects
# * M1E: Firm size group random effects
#
# ### Joint Random Effect Models (M1F–M4F)
#
# Add multiple random effects simultaneously to assess whether fixed effects remain stable when accounting for both firm size and occupation simultaneously:
#
# * M1F: Baseline fixed effects + firm size + occupation
# * M2F: Adds gender × mobility interactions
# * M3F: Adds race × mobility interactions
# * M4F: Stratified by gender, with race × mobility interactions
#
# ## Outputs
#
# For each model, the notebook:
#
# * Prints posterior summaries to the console.
# * Exports a single tidy results table (.csv) containing:
#
#   * Posterior means and SDs for fixed effects
#   * Odds ratios and 95% credibility intervals
#   * Variance components for each random effect grouping variable
#   * Credibility flags indicating whether intervals exclude OR = 1 (for fixed) or τ = 0 (for random)
#
# This unified output format makes it easy to compare results across multiple robustness checks.
#
# ## Reproducibility
#
# To replicate the sensitivity analysis:
#
# 1. Place the pre-processed Parquet dataset in the `data/` directory.
# 2. Open the notebook in Jupyter or JupyterLab.
# 3. Execute cells sequentially.
# 4. Review exported CSV tables for fixed and random effects.
#
# ## Dependencies
#
# * Python 3.8+
# * [pandas](https://pandas.pydata.org/)
# * [numpy](https://numpy.org/)
# * [statsmodels](https://www.statsmodels.org/) (Bayesian Mixed GLM module)

# %%
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import time

# Filename breakdown: using LightCast (LC) partitions 0 to 19 (20 partitions) covering the first 5-year career of individual workers
data_filename = f'../data/lc0-19_job_pairs_y1-5_final.parquet'

def load_datatable(data_filename):
    df = pd.read_parquet(data_filename)

    # Random-effect (RE) variables: state and firm size group
    df.rename(columns={'STATE_RAW_x': 'state_x'}, inplace=True)
    
    df.rename(columns={'COMPANY_NAME_x': 'company_x'}, inplace=True)
    
    # Since # obvs per firm is extrmeley sparse (median = 2), we'll group firms into #obvs buckets
    firm_counts = df.groupby('company_x').size()
    df['per_company_obs_x'] = df['company_x'].map(firm_counts)
    
    conditions = [
        # Group 1: Sparse/Transient (N < 10) 
        (df['per_company_obs_x'] < 10),
    
        # Group 2: Medium (10 <= N <= 100)
        (df['per_company_obs_x'] >= 10) & (df['per_company_obs_x'] <= 100),
    
        # Group 3: Large (101 <= N <= 300)
        (df['per_company_obs_x'] >= 101) & (df['per_company_obs_x'] <= 300),
    
        # Group 4: Major/Mega (> 300)
        (df['per_company_obs_x'] > 300)
    ]
    
    values = [
        'Sparse_N<10',
        'Medium_N10-100',
        'Large_N101-300',
        'Mega_N>300'
    ]
     
    df['firm_obs_group_x'] = np.select(conditions, values, default='Error')
    df['firm_obs_group_x'] = df['firm_obs_group_x'].astype('category')
    
    df = df[[
        'up_move',
        'gender',
        'race',
        'onet_major_x',
        'nacis6_major_x', 
        'max_edu_name',
        'generation',
        'firm_obs_group_x', # Firm size group (RE)
        'job_start_year_x', # Career entry year (RE)
        'state_x',
        'state_gdp_decile_x',
        'num_job_changes',
        'log_wage_x',
        'move_1_1', # Type-1 job movement
        'move_1_2', # Type-2 job movement
        'move_2_1', # Type-3 job movement
    ]]
    return df

df = load_datatable(data_filename)

# %% [markdown]
# # Sensitivity Analyis

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.genmod.bayes_mixed_glm import BinomialBayesMixedGLM
import statsmodels.formula.api as smf
import time
import warnings

warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)

# --- Fitting Binomial Bayes Mixed GLM with Variational Bayes inference given FE formula and RE formula ---

def run_mglm(fixed_formula, random_formula, output_filename, maxiter=2500, gtol=5e-4):

    # Scaling continuous variables using z-scores to improve convergence time
    mean_gdp = df['state_gdp_decile_x'].mean()
    std_gdp = df['state_gdp_decile_x'].std()
    mean_changes = df['num_job_changes'].mean()
    std_changes = df['num_job_changes'].std()
    mean_wage = df['log_wage_x'].mean()
    std_wage = df['log_wage_x'].std()
    
    df['state_gdp_decile_x_scaled'] = (df['state_gdp_decile_x'] - mean_gdp) / std_gdp
    df['num_job_changes_scaled'] = (df['num_job_changes'] - mean_changes) / std_changes
    df['log_wage_x_scaled'] = (df['log_wage_x'] - mean_wage) / std_wage
    
    model = BinomialBayesMixedGLM.from_formula(
        formula=fixed_formula,
        vc_formulas=random_formula,
        data=df
    )
    
    start = time.time()
    results = model.fit_vb(
        minim_opts={
            'maxiter': maxiter,
            'gtol': gtol
        }
    )
    end = time.time()
    print(f"Done in {end-start:.2f} sec")
    print(results.summary())

    
    # --- Fixed Effect Export  ---
    fixed_param_names = results.model.exog_names 
    fe_mean = results.fe_mean
    fe_sd = results.fe_sd
    Z_SCORE_95 = 1.96
    
    margin_of_error = Z_SCORE_95 * fe_sd
    or_lb = np.exp(fe_mean - margin_of_error)
    or_ub = np.exp(fe_mean + margin_of_error)
    
    df_fixed = pd.DataFrame({
        'Parameter': fixed_param_names, 
        'Type': 'Fixed (M)',
        'Post. Mean (Log-Odds)': fe_mean,
        'Post. SD': fe_sd,
        'Odds Ratio (OR)': np.exp(fe_mean),
        '95% CI LB (OR)': or_lb,
        '95% CI UB (OR)': or_ub,
        'Credibility': ~((or_lb < 1) & (or_ub > 1))
    })
    
    
    # --- Random Effect Export ---
    
    df_random_list = []
    re_keys = list(random_formula.keys())
    
    try:
        # Loop through each Random Effect based on the length of results.vcp_mean
        for i in range(len(results.vcp_mean)):
            re_key = re_keys[i]
            
            # Retrieve specific posterior means and SDs for the i-th RE
            vcp_mean_log_tau = results.vcp_mean[i]
            vcp_sd_log_tau = results.vcp_sd[i]
            
            # Calculate CI bounds for log(tau)
            log_tau_lb = vcp_mean_log_tau - Z_SCORE_95 * vcp_sd_log_tau
            log_tau_ub = vcp_mean_log_tau + Z_SCORE_95 * vcp_sd_log_tau
            
            # Transform CI bounds back to the tau (SD) scale
            tau_lb = np.exp(log_tau_lb)
            tau_ub = np.exp(log_tau_ub)
            
            # Use the point estimate on the tau scale:
            tau_estimate = np.exp(vcp_mean_log_tau) 
            
            # Collect data for the current RE
            df_random_list.append(pd.DataFrame({
                'Parameter': [re_key],
                'Type': ['Random (V)'],
                'Post. Mean (Log-Odds)': [tau_estimate],
                'Post. SD': [vcp_sd_log_tau], # Use SD of log(tau)
                'Odds Ratio (OR)': ['N/A'],
                '95% CI LB (OR)': [tau_lb],
                '95% CI UB (OR)': [tau_ub],
                'Credibility': [tau_lb > 0] 
            }))
            
    except IndexError:
         raise RuntimeError("Mismatch between provided random_formula keys and model results structure.")
    except Exception as e:
         raise RuntimeError(f"Failed to process Random Effects: {e}")
         
    # Concatenate all collected fixed and random effect dataframes
    if df_random_list:
        df_random = pd.concat(df_random_list, ignore_index=True)
    else:
        df_random = pd.DataFrame() # Handle case with no REs (though unlikely here)
        
    final_df = pd.concat([df_fixed, df_random], ignore_index=True)
    
    # --- Formatting and Export ---
    
    # 1. RENAME COLUMNS 
    final_df = final_df.rename(columns={
        'Post. Mean (Log-Odds)': 'Post. Mean (Log-Odds | SD/tau)',
        '95% CI LB (OR)': '95% CI LB (OR | tau)',
        '95% CI UB (OR)': '95% CI UB (OR | tau)'
    })
    
    # Identify fixed and random rows for separate formatting
    fixed_rows_mask = final_df['Type'] == 'Fixed (M)'
    random_rows_mask = final_df['Type'] == 'Random (V)'
    
    # 2. Format Fixed Effects (numeric - unchanged logic)
    numeric_cols_to_format = ['Post. Mean (Log-Odds | SD/tau)', 'Post. SD', 'Odds Ratio (OR)', '95% CI LB (OR | tau)', '95% CI UB (OR | tau)']
    
    for col in numeric_cols_to_format:
        if col in final_df.columns:
            final_df.loc[fixed_rows_mask, col] = pd.to_numeric(
                final_df.loc[fixed_rows_mask, col], errors='coerce'
            ).round(4)
            
    # 3. Format Random Effect Rows
    for index in final_df[random_rows_mask].index:
        tau_est_val = final_df.loc[index, 'Post. Mean (Log-Odds | SD/tau)']
        tau_sd_val = final_df.loc[index, 'Post. SD']
        tau_lb_val = final_df.loc[index, '95% CI LB (OR | tau)']
        tau_ub_val = final_df.loc[index, '95% CI UB (OR | tau)']
        
        # Apply string formatting to each RE row
        final_df.loc[index, 'Post. Mean (Log-Odds | SD/tau)'] = f"{tau_est_val:.4f}"
        final_df.loc[index, 'Post. SD'] = f"{tau_sd_val:.4f}"
        final_df.loc[index, 'Odds Ratio (OR)'] = 'N/A'
        final_df.loc[index, '95% CI LB (OR | tau)'] = f"{tau_lb_val:.4f}"
        final_df.loc[index, '95% CI UB (OR | tau)'] = f"{tau_ub_val:.4f}"
    
    final_df.to_csv(output_filename, index=False)
    print(f"Exported results table to {output_filename}")

# %% [markdown]
# ## Robustness Tests for Individual RE Components

# %% [markdown]
# ### Mode1A: Year 1 Major SOC Groups as RE

# %%
df = load_datatable(data_filename)
output_filename = f'../results/mglm_m1a.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled'
)
random_formula = {
    'onet_group_re': '0 + C(onet_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 785.62 sec
#                            Binomial Mixed GLM Results
# =================================================================================
#                                    Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ---------------------------------------------------------------------------------
# Intercept                             M    -1.1047   0.0050
# C(gender)[T.2]                        M    -0.1534   0.0072
# C(race)[T.2]                          M    -0.0703   0.0135
# C(race)[T.3]                          M     0.1331   0.0140
# C(race)[T.4]                          M     0.0234   0.0178
# C(move_1_1)[T.1]                      M     0.9354   0.0070
# C(move_1_2)[T.1]                      M     0.9527   0.0104
# C(move_2_1)[T.1]                      M     0.7982   0.0114
# C(onet_major_x)[T.13]                 M     0.4683   0.0118
# C(onet_major_x)[T.15]                 M     0.4231   0.0161
# C(onet_major_x)[T.17]                 M     0.4045   0.0192
# C(onet_major_x)[T.19]                 M    -0.0459   0.0234
# C(onet_major_x)[T.21]                 M    -0.1592   0.0305
# C(onet_major_x)[T.23]                 M    -0.0849   0.0343
# C(onet_major_x)[T.25]                 M    -0.2012   0.0190
# C(onet_major_x)[T.27]                 M    -0.1056   0.0207
# C(onet_major_x)[T.29]                 M     0.2295   0.0236
# C(onet_major_x)[T.31]                 M     0.1314   0.0829
# C(onet_major_x)[T.33]                 M    -0.1920   0.0656
# C(onet_major_x)[T.35]                 M    -0.3340   0.0597
# C(onet_major_x)[T.37]                 M    -0.1490   0.1472
# C(onet_major_x)[T.39]                 M    -0.2593   0.0548
# C(onet_major_x)[T.41]                 M     0.1710   0.0162
# C(onet_major_x)[T.43]                 M     0.1483   0.0197
# C(onet_major_x)[T.45]                 M    -0.0332   0.2516
# C(onet_major_x)[T.47]                 M    -0.0532   0.0987
# C(onet_major_x)[T.49]                 M    -0.1500   0.0735
# C(onet_major_x)[T.51]                 M     0.0398   0.0602
# C(onet_major_x)[T.53]                 M    -0.0906   0.0707
# C(nacis6_major_x)[T.21]               M     0.2262   0.0578
# C(nacis6_major_x)[T.22]               M     0.2431   0.0556
# C(nacis6_major_x)[T.23]               M     0.2222   0.0283
# C(nacis6_major_x)[T.31]               M     0.3143   0.0383
# C(nacis6_major_x)[T.32]               M     0.1893   0.0321
# C(nacis6_major_x)[T.33]               M     0.2607   0.0169
# C(nacis6_major_x)[T.42]               M     0.2851   0.0264
# C(nacis6_major_x)[T.44]               M    -0.1142   0.0244
# C(nacis6_major_x)[T.45]               M    -0.0609   0.0292
# C(nacis6_major_x)[T.48]               M     0.1050   0.0444
# C(nacis6_major_x)[T.49]               M     0.0810   0.0728
# C(nacis6_major_x)[T.51]               M     0.2213   0.0221
# C(nacis6_major_x)[T.52]               M     0.2295   0.0155
# C(nacis6_major_x)[T.53]               M     0.0427   0.0332
# C(nacis6_major_x)[T.54]               M     0.2149   0.0128
# C(nacis6_major_x)[T.55]               M     0.1575   0.0767
# C(nacis6_major_x)[T.56]               M     0.0592   0.0297
# C(nacis6_major_x)[T.61]               M    -0.1915   0.0134
# C(nacis6_major_x)[T.62]               M    -0.0372   0.0169
# C(nacis6_major_x)[T.71]               M    -0.1339   0.0388
# C(nacis6_major_x)[T.72]               M    -0.0249   0.0331
# C(nacis6_major_x)[T.81]               M    -0.0943   0.0310
# C(nacis6_major_x)[T.92]               M    -0.1141   0.0335
# C(max_edu_name)[T.Doctorate]          M     1.2081   0.0234
# C(max_edu_name)[T.Master's Degree]    M     0.4090   0.0110
# C(generation)[T.Millennials]          M     0.1744   0.0057
# state_gdp_decile_x_scaled             M     0.0416   0.0051
# num_job_changes_scaled                M     0.5950   0.0057
# log_wage_x_scaled                     M    -0.9984   0.0055
# onet_group_re                         V    -4.2858   0.1657 0.014   0.010   0.019
# =================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m1a.csv

# %% [markdown]
# ### Model 1B: Year-1 Major NAICS Groups as RE

# %%
df = load_datatable(data_filename)
output_filename = f'data/mglm_m1b.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled'
)
random_formula = {
    'naics_group_re': '0 + C(nacis6_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 817.64 sec
#                            Binomial Mixed GLM Results
# =================================================================================
#                                    Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ---------------------------------------------------------------------------------
# Intercept                             M    -1.1046   0.0051
# C(gender)[T.2]                        M    -0.1534   0.0072
# C(race)[T.2]                          M    -0.0703   0.0135
# C(race)[T.3]                          M     0.1331   0.0140
# C(race)[T.4]                          M     0.0234   0.0178
# C(move_1_1)[T.1]                      M     0.9354   0.0070
# C(move_1_2)[T.1]                      M     0.9527   0.0104
# C(move_2_1)[T.1]                      M     0.7982   0.0114
# C(onet_major_x)[T.13]                 M     0.4683   0.0118
# C(onet_major_x)[T.15]                 M     0.4232   0.0161
# C(onet_major_x)[T.17]                 M     0.4046   0.0192
# C(onet_major_x)[T.19]                 M    -0.0459   0.0234
# C(onet_major_x)[T.21]                 M    -0.1592   0.0305
# C(onet_major_x)[T.23]                 M    -0.0848   0.0343
# C(onet_major_x)[T.25]                 M    -0.2011   0.0190
# C(onet_major_x)[T.27]                 M    -0.1055   0.0207
# C(onet_major_x)[T.29]                 M     0.2296   0.0236
# C(onet_major_x)[T.31]                 M     0.1315   0.0829
# C(onet_major_x)[T.33]                 M    -0.1920   0.0656
# C(onet_major_x)[T.35]                 M    -0.3339   0.0597
# C(onet_major_x)[T.37]                 M    -0.1489   0.1472
# C(onet_major_x)[T.39]                 M    -0.2592   0.0548
# C(onet_major_x)[T.41]                 M     0.1710   0.0162
# C(onet_major_x)[T.43]                 M     0.1484   0.0197
# C(onet_major_x)[T.45]                 M    -0.0332   0.2516
# C(onet_major_x)[T.47]                 M    -0.0531   0.0987
# C(onet_major_x)[T.49]                 M    -0.1499   0.0735
# C(onet_major_x)[T.51]                 M     0.0399   0.0602
# C(onet_major_x)[T.53]                 M    -0.0905   0.0707
# C(nacis6_major_x)[T.21]               M     0.2260   0.0578
# C(nacis6_major_x)[T.22]               M     0.2429   0.0556
# C(nacis6_major_x)[T.23]               M     0.2220   0.0283
# C(nacis6_major_x)[T.31]               M     0.3142   0.0383
# C(nacis6_major_x)[T.32]               M     0.1892   0.0320
# C(nacis6_major_x)[T.33]               M     0.2606   0.0169
# C(nacis6_major_x)[T.42]               M     0.2849   0.0264
# C(nacis6_major_x)[T.44]               M    -0.1143   0.0244
# C(nacis6_major_x)[T.45]               M    -0.0610   0.0292
# C(nacis6_major_x)[T.48]               M     0.1049   0.0444
# C(nacis6_major_x)[T.49]               M     0.0809   0.0728
# C(nacis6_major_x)[T.51]               M     0.2212   0.0221
# C(nacis6_major_x)[T.52]               M     0.2294   0.0155
# C(nacis6_major_x)[T.53]               M     0.0426   0.0332
# C(nacis6_major_x)[T.54]               M     0.2147   0.0128
# C(nacis6_major_x)[T.55]               M     0.1574   0.0767
# C(nacis6_major_x)[T.56]               M     0.0590   0.0297
# C(nacis6_major_x)[T.61]               M    -0.1916   0.0134
# C(nacis6_major_x)[T.62]               M    -0.0374   0.0169
# C(nacis6_major_x)[T.71]               M    -0.1340   0.0388
# C(nacis6_major_x)[T.72]               M    -0.0251   0.0331
# C(nacis6_major_x)[T.81]               M    -0.0944   0.0310
# C(nacis6_major_x)[T.92]               M    -0.1142   0.0335
# C(max_edu_name)[T.Doctorate]          M     1.2081   0.0234
# C(max_edu_name)[T.Master's Degree]    M     0.4090   0.0110
# C(generation)[T.Millennials]          M     0.1744   0.0057
# state_gdp_decile_x_scaled             M     0.0416   0.0051
# num_job_changes_scaled                M     0.5950   0.0057
# log_wage_x_scaled                     M    -0.9984   0.0055
# naics_group_re                        V    -4.3386   0.1575 0.013   0.010   0.018
# =================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m1b.csv

# %% [markdown]
# ### Model 1C: Year-1 States as RE

# %%
df = load_datatable(data_filename)
output_filename = f'../results/mglm_m1c.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(state_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled'
)
random_formula = {
    'state_group_re': '0 + C(state_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 1562.55 sec
#                            Binomial Mixed GLM Results
# =================================================================================
#                                    Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ---------------------------------------------------------------------------------
# Intercept                             M    -0.9937   0.0051
# C(gender)[T.2]                        M    -0.1566   0.0072
# C(race)[T.2]                          M    -0.0690   0.0135
# C(race)[T.3]                          M     0.1302   0.0140
# C(race)[T.4]                          M     0.0217   0.0178
# C(move_1_1)[T.1]                      M     0.9333   0.0070
# C(move_1_2)[T.1]                      M     0.9529   0.0104
# C(move_2_1)[T.1]                      M     0.7991   0.0114
# C(onet_major_x)[T.13]                 M     0.4416   0.0118
# C(onet_major_x)[T.15]                 M     0.4112   0.0161
# C(onet_major_x)[T.17]                 M     0.4020   0.0192
# C(onet_major_x)[T.19]                 M    -0.0731   0.0234
# C(onet_major_x)[T.21]                 M    -0.1912   0.0305
# C(onet_major_x)[T.23]                 M    -0.0997   0.0343
# C(onet_major_x)[T.25]                 M    -0.2315   0.0190
# C(onet_major_x)[T.27]                 M    -0.1377   0.0207
# C(onet_major_x)[T.29]                 M     0.2137   0.0237
# C(onet_major_x)[T.31]                 M     0.0779   0.0829
# C(onet_major_x)[T.33]                 M    -0.2116   0.0657
# C(onet_major_x)[T.35]                 M    -0.4023   0.0597
# C(onet_major_x)[T.37]                 M    -0.1945   0.1473
# C(onet_major_x)[T.39]                 M    -0.3075   0.0548
# C(onet_major_x)[T.41]                 M     0.1499   0.0162
# C(onet_major_x)[T.43]                 M     0.1084   0.0197
# C(onet_major_x)[T.45]                 M    -0.0706   0.2520
# C(onet_major_x)[T.47]                 M    -0.0742   0.0988
# C(onet_major_x)[T.49]                 M    -0.1687   0.0736
# C(onet_major_x)[T.51]                 M     0.0064   0.0603
# C(onet_major_x)[T.53]                 M    -0.1219   0.0709
# C(nacis6_major_x)[T.21]               M     0.2486   0.0579
# C(nacis6_major_x)[T.22]               M     0.2666   0.0556
# C(nacis6_major_x)[T.23]               M     0.2107   0.0283
# C(nacis6_major_x)[T.31]               M     0.3265   0.0383
# C(nacis6_major_x)[T.32]               M     0.2120   0.0320
# C(nacis6_major_x)[T.33]               M     0.2737   0.0169
# C(nacis6_major_x)[T.42]               M     0.3110   0.0264
# C(nacis6_major_x)[T.44]               M    -0.1182   0.0245
# C(nacis6_major_x)[T.45]               M    -0.0587   0.0292
# C(nacis6_major_x)[T.48]               M     0.1244   0.0444
# C(nacis6_major_x)[T.49]               M     0.1013   0.0729
# C(nacis6_major_x)[T.51]               M     0.2269   0.0221
# C(nacis6_major_x)[T.52]               M     0.2168   0.0155
# C(nacis6_major_x)[T.53]               M     0.0597   0.0332
# C(nacis6_major_x)[T.54]               M     0.2197   0.0128
# C(nacis6_major_x)[T.55]               M     0.1786   0.0767
# C(nacis6_major_x)[T.56]               M     0.0722   0.0297
# C(nacis6_major_x)[T.61]               M    -0.1838   0.0134
# C(nacis6_major_x)[T.62]               M    -0.0326   0.0169
# C(nacis6_major_x)[T.71]               M    -0.1337   0.0388
# C(nacis6_major_x)[T.72]               M    -0.0066   0.0331
# C(nacis6_major_x)[T.81]               M    -0.0903   0.0311
# C(nacis6_major_x)[T.92]               M    -0.1123   0.0335
# C(state_x)[T.Alaska]                  M     0.3117   0.1872
# C(state_x)[T.Arizona]                 M    -0.0045   0.0449
# C(state_x)[T.Arkansas]                M     0.0416   0.0637
# C(state_x)[T.California]              M    -0.1984   0.0143
# C(state_x)[T.Colorado]                M     0.0105   0.0385
# C(state_x)[T.Connecticut]             M     0.0672   0.0412
# C(state_x)[T.Delaware]                M     0.2312   0.1108
# C(state_x)[T.Florida]                 M    -0.2298   0.0273
# C(state_x)[T.Georgia]                 M    -0.1162   0.0288
# C(state_x)[T.Hawaii]                  M    -0.0134   0.1672
# C(state_x)[T.Idaho]                   M     0.3012   0.1117
# C(state_x)[T.Illinois]                M    -0.2083   0.0195
# C(state_x)[T.Indiana]                 M    -0.0353   0.0408
# C(state_x)[T.Iowa]                    M     0.0706   0.0608
# C(state_x)[T.Kansas]                  M     0.1047   0.0588
# C(state_x)[T.Kentucky]                M     0.0513   0.0629
# C(state_x)[T.Louisiana]               M    -0.1232   0.0690
# C(state_x)[T.Maine]                   M     0.1609   0.1232
# C(state_x)[T.Maryland]                M    -0.0456   0.0307
# C(state_x)[T.Massachusetts]           M    -0.0058   0.0228
# C(state_x)[T.Michigan]                M    -0.1704   0.0309
# C(state_x)[T.Minnesota]               M    -0.0556   0.0296
# C(state_x)[T.Mississippi]             M    -0.1301   0.1276
# C(state_x)[T.Missouri]                M    -0.0453   0.0326
# C(state_x)[T.Montana]                 M     0.2285   0.1661
# C(state_x)[T.Nebraska]                M     0.1923   0.0651
# C(state_x)[T.Nevada]                  M     0.1767   0.0847
# C(state_x)[T.New Hampshire]           M     0.5845   0.0992
# C(state_x)[T.New Jersey]              M    -0.2122   0.0281
# C(state_x)[T.New Mexico]              M     0.2383   0.1330
# C(state_x)[T.New York]                M    -0.0495   0.0143
# C(state_x)[T.North Carolina]          M     0.0302   0.0311
# C(state_x)[T.North Dakota]            M     0.3739   0.1477
# C(state_x)[T.Ohio]                    M    -0.2005   0.0254
# C(state_x)[T.Oklahoma]                M     0.0441   0.0695
# C(state_x)[T.Oregon]                  M     0.1217   0.0551
# C(state_x)[T.Pennsylvania]            M    -0.1520   0.0257
# C(state_x)[T.Rhode Island]            M     0.3877   0.0787
# C(state_x)[T.South Carolina]          M     0.0933   0.0638
# C(state_x)[T.South Dakota]            M     0.2206   0.1508
# C(state_x)[T.Tennessee]               M    -0.0523   0.0440
# C(state_x)[T.Texas]                   M    -0.1788   0.0190
# C(state_x)[T.Utah]                    M     0.1980   0.0604
# C(state_x)[T.Vermont]                 M     0.4147   0.1416
# C(state_x)[T.Virginia]                M    -0.1135   0.0256
# C(state_x)[T.Washington]              M     0.0893   0.0329
# C(state_x)[T.West Virginia]           M     0.2278   0.1427
# C(state_x)[T.Wisconsin]               M    -0.0675   0.0358
# C(state_x)[T.Wyoming]                 M     0.4371   0.1982
# C(max_edu_name)[T.Doctorate]          M     1.2153   0.0235
# C(max_edu_name)[T.Master's Degree]    M     0.4079   0.0110
# C(generation)[T.Millennials]          M     0.1690   0.0057
# state_gdp_decile_x_scaled             M     0.1391   0.0051
# num_job_changes_scaled                M     0.5945   0.0057
# log_wage_x_scaled                     M    -1.0179   0.0055
# state_group_re                        V    -4.4104   0.1042 0.012   0.010   0.015
# =================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m1c.csv

# %% [markdown]
# ### Model 1D: Year 1 Cohort as RE

# %%
df = load_datatable(data_filename)
output_filename = f'data/mglm_m1d.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(job_start_year_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled'
)
random_formula = {
    'job_start_year_group_re': '0 + C(job_start_year_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 1021.39 sec
#                            Binomial Mixed GLM Results
# =================================================================================
#                                    Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ---------------------------------------------------------------------------------
# Intercept                             M    -1.3167   0.0051
# C(gender)[T.2]                        M    -0.1546   0.0072
# C(race)[T.2]                          M    -0.0730   0.0135
# C(race)[T.3]                          M     0.1288   0.0140
# C(race)[T.4]                          M     0.0192   0.0178
# C(move_1_1)[T.1]                      M     0.9316   0.0070
# C(move_1_2)[T.1]                      M     0.9492   0.0104
# C(move_2_1)[T.1]                      M     0.7974   0.0114
# C(onet_major_x)[T.13]                 M     0.4504   0.0118
# C(onet_major_x)[T.15]                 M     0.4104   0.0161
# C(onet_major_x)[T.17]                 M     0.3896   0.0192
# C(onet_major_x)[T.19]                 M    -0.0736   0.0234
# C(onet_major_x)[T.21]                 M    -0.1905   0.0305
# C(onet_major_x)[T.23]                 M    -0.0948   0.0343
# C(onet_major_x)[T.25]                 M    -0.2294   0.0190
# C(onet_major_x)[T.27]                 M    -0.1293   0.0207
# C(onet_major_x)[T.29]                 M     0.2097   0.0237
# C(onet_major_x)[T.31]                 M     0.0706   0.0830
# C(onet_major_x)[T.33]                 M    -0.2259   0.0657
# C(onet_major_x)[T.35]                 M    -0.3883   0.0597
# C(onet_major_x)[T.37]                 M    -0.1827   0.1471
# C(onet_major_x)[T.39]                 M    -0.3078   0.0548
# C(onet_major_x)[T.41]                 M     0.1465   0.0162
# C(onet_major_x)[T.43]                 M     0.1069   0.0197
# C(onet_major_x)[T.45]                 M    -0.0861   0.2521
# C(onet_major_x)[T.47]                 M    -0.0863   0.0987
# C(onet_major_x)[T.49]                 M    -0.1858   0.0735
# C(onet_major_x)[T.51]                 M     0.0007   0.0603
# C(onet_major_x)[T.53]                 M    -0.1298   0.0709
# C(nacis6_major_x)[T.21]               M     0.2373   0.0579
# C(nacis6_major_x)[T.22]               M     0.2523   0.0556
# C(nacis6_major_x)[T.23]               M     0.2283   0.0283
# C(nacis6_major_x)[T.31]               M     0.3212   0.0383
# C(nacis6_major_x)[T.32]               M     0.2010   0.0321
# C(nacis6_major_x)[T.33]               M     0.2759   0.0170
# C(nacis6_major_x)[T.42]               M     0.2939   0.0264
# C(nacis6_major_x)[T.44]               M    -0.1138   0.0245
# C(nacis6_major_x)[T.45]               M    -0.0593   0.0292
# C(nacis6_major_x)[T.48]               M     0.1062   0.0444
# C(nacis6_major_x)[T.49]               M     0.0876   0.0728
# C(nacis6_major_x)[T.51]               M     0.2326   0.0221
# C(nacis6_major_x)[T.52]               M     0.2411   0.0155
# C(nacis6_major_x)[T.53]               M     0.0452   0.0332
# C(nacis6_major_x)[T.54]               M     0.2218   0.0128
# C(nacis6_major_x)[T.55]               M     0.1625   0.0767
# C(nacis6_major_x)[T.56]               M     0.0588   0.0297
# C(nacis6_major_x)[T.61]               M    -0.1898   0.0134
# C(nacis6_major_x)[T.62]               M    -0.0367   0.0169
# C(nacis6_major_x)[T.71]               M    -0.1308   0.0388
# C(nacis6_major_x)[T.72]               M    -0.0263   0.0331
# C(nacis6_major_x)[T.81]               M    -0.0920   0.0310
# C(nacis6_major_x)[T.92]               M    -0.1028   0.0335
# C(job_start_year_x)[T.2000]           M     0.0975   0.0273
# C(job_start_year_x)[T.2001]           M     0.1792   0.0285
# C(job_start_year_x)[T.2002]           M     0.2674   0.0284
# C(job_start_year_x)[T.2003]           M     0.3130   0.0271
# C(job_start_year_x)[T.2004]           M     0.3360   0.0229
# C(job_start_year_x)[T.2005]           M     0.3298   0.0206
# C(job_start_year_x)[T.2006]           M     0.3337   0.0197
# C(job_start_year_x)[T.2007]           M     0.2902   0.0187
# C(job_start_year_x)[T.2008]           M     0.2394   0.0188
# C(job_start_year_x)[T.2009]           M     0.2617   0.0203
# C(job_start_year_x)[T.2010]           M     0.2702   0.0188
# C(job_start_year_x)[T.2011]           M     0.3109   0.0181
# C(job_start_year_x)[T.2012]           M     0.3586   0.0177
# C(job_start_year_x)[T.2013]           M     0.4212   0.0183
# C(job_start_year_x)[T.2014]           M     0.3824   0.0197
# C(job_start_year_x)[T.2015]           M     0.3666   0.0224
# C(job_start_year_x)[T.2016]           M     0.4677   0.0290
# C(job_start_year_x)[T.2017]           M     0.3555   0.0783
# C(max_edu_name)[T.Doctorate]          M     1.2037   0.0235
# C(max_edu_name)[T.Master's Degree]    M     0.4057   0.0110
# C(generation)[T.Millennials]          M     0.0788   0.0057
# state_gdp_decile_x_scaled             M     0.0411   0.0051
# num_job_changes_scaled                M     0.5864   0.0057
# log_wage_x_scaled                     M    -1.0165   0.0055
# job_start_year_group_re               V    -4.3656   0.1818 0.013   0.009   0.018
# =================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m1d.csv

# %% [markdown]
# ### Model 1E: Year 1 Firm Size as RE

# %%
df = load_datatable(data_filename)
output_filename = f'../results/mglm_m1e.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(firm_obs_group_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled'
)
random_formula = {
    'firm_obs_group_re': '0 + C(firm_obs_group_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 780.24 sec
#                              Binomial Mixed GLM Results
# ====================================================================================
#                                       Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ------------------------------------------------------------------------------------
# Intercept                                M    -1.0581   0.0051
# C(gender)[T.2]                           M    -0.1520   0.0072
# C(race)[T.2]                             M    -0.0717   0.0135
# C(race)[T.3]                             M     0.1270   0.0140
# C(race)[T.4]                             M     0.0236   0.0178
# C(move_1_1)[T.1]                         M     0.9409   0.0070
# C(move_1_2)[T.1]                         M     0.9483   0.0104
# C(move_2_1)[T.1]                         M     0.8054   0.0114
# C(onet_major_x)[T.13]                    M     0.4557   0.0118
# C(onet_major_x)[T.15]                    M     0.4135   0.0161
# C(onet_major_x)[T.17]                    M     0.4076   0.0191
# C(onet_major_x)[T.19]                    M    -0.0553   0.0234
# C(onet_major_x)[T.21]                    M    -0.1498   0.0305
# C(onet_major_x)[T.23]                    M    -0.0745   0.0343
# C(onet_major_x)[T.25]                    M    -0.2010   0.0190
# C(onet_major_x)[T.27]                    M    -0.0941   0.0207
# C(onet_major_x)[T.29]                    M     0.2167   0.0236
# C(onet_major_x)[T.31]                    M     0.1317   0.0829
# C(onet_major_x)[T.33]                    M    -0.1961   0.0657
# C(onet_major_x)[T.35]                    M    -0.3443   0.0597
# C(onet_major_x)[T.37]                    M    -0.1464   0.1474
# C(onet_major_x)[T.39]                    M    -0.2638   0.0548
# C(onet_major_x)[T.41]                    M     0.1602   0.0162
# C(onet_major_x)[T.43]                    M     0.1465   0.0197
# C(onet_major_x)[T.45]                    M    -0.0225   0.2517
# C(onet_major_x)[T.47]                    M    -0.0388   0.0987
# C(onet_major_x)[T.49]                    M    -0.1498   0.0735
# C(onet_major_x)[T.51]                    M     0.0447   0.0603
# C(onet_major_x)[T.53]                    M    -0.1019   0.0707
# C(nacis6_major_x)[T.21]                  M     0.1988   0.0578
# C(nacis6_major_x)[T.22]                  M     0.2163   0.0556
# C(nacis6_major_x)[T.23]                  M     0.1997   0.0283
# C(nacis6_major_x)[T.31]                  M     0.2798   0.0383
# C(nacis6_major_x)[T.32]                  M     0.1637   0.0320
# C(nacis6_major_x)[T.33]                  M     0.2138   0.0169
# C(nacis6_major_x)[T.42]                  M     0.2732   0.0264
# C(nacis6_major_x)[T.44]                  M    -0.1564   0.0245
# C(nacis6_major_x)[T.45]                  M    -0.1174   0.0292
# C(nacis6_major_x)[T.48]                  M     0.0858   0.0444
# C(nacis6_major_x)[T.49]                  M     0.0387   0.0728
# C(nacis6_major_x)[T.51]                  M     0.1818   0.0221
# C(nacis6_major_x)[T.52]                  M     0.1801   0.0155
# C(nacis6_major_x)[T.53]                  M     0.0099   0.0332
# C(nacis6_major_x)[T.54]                  M     0.2007   0.0128
# C(nacis6_major_x)[T.55]                  M     0.1439   0.0767
# C(nacis6_major_x)[T.56]                  M     0.0433   0.0297
# C(nacis6_major_x)[T.61]                  M    -0.2277   0.0134
# C(nacis6_major_x)[T.62]                  M    -0.0536   0.0169
# C(nacis6_major_x)[T.71]                  M    -0.1404   0.0388
# C(nacis6_major_x)[T.72]                  M    -0.0502   0.0331
# C(nacis6_major_x)[T.81]                  M    -0.0960   0.0310
# C(nacis6_major_x)[T.92]                  M    -0.1648   0.0335
# C(firm_obs_group_x)[T.Medium_N10-100]    M     0.0135   0.0092
# C(firm_obs_group_x)[T.Mega_N>300]        M     0.0516   0.0130
# C(firm_obs_group_x)[T.Sparse_N<10]       M    -0.0745   0.0080
# C(max_edu_name)[T.Doctorate]             M     1.2010   0.0234
# C(max_edu_name)[T.Master's Degree]       M     0.4053   0.0110
# C(generation)[T.Millennials]             M     0.1797   0.0057
# state_gdp_decile_x_scaled                M     0.0364   0.0051
# num_job_changes_scaled                   M     0.5935   0.0057
# log_wage_x_scaled                        M    -1.0004   0.0055
# firm_obs_group_re                        V    -3.3094   0.6480 0.037   0.010   0.134
# ====================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m1e_2.csv

# %% [markdown]
# ## Robustness Tests for Joint Random Effects

# %% [markdown]
# ### Model 1F: Year 1 Firm Size + Occupation as REs

# %%
df = load_datatable(data_filename)
output_filename = f'data/mglm_m1f.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(firm_obs_group_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled'
)
random_formula = {
    'firm_obs_group_re': '0 + C(firm_obs_group_x)',
    'onet_group_re': '0 + C(onet_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 969.74 sec
#                              Binomial Mixed GLM Results
# ====================================================================================
#                                       Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ------------------------------------------------------------------------------------
# Intercept                                M    -1.0580   0.0051
# C(gender)[T.2]                           M    -0.1520   0.0072
# C(race)[T.2]                             M    -0.0717   0.0135
# C(race)[T.3]                             M     0.1270   0.0140
# C(race)[T.4]                             M     0.0236   0.0178
# C(move_1_1)[T.1]                         M     0.9409   0.0070
# C(move_1_2)[T.1]                         M     0.9484   0.0104
# C(move_2_1)[T.1]                         M     0.8054   0.0114
# C(onet_major_x)[T.13]                    M     0.4557   0.0118
# C(onet_major_x)[T.15]                    M     0.4134   0.0161
# C(onet_major_x)[T.17]                    M     0.4075   0.0191
# C(onet_major_x)[T.19]                    M    -0.0554   0.0234
# C(onet_major_x)[T.21]                    M    -0.1498   0.0305
# C(onet_major_x)[T.23]                    M    -0.0745   0.0343
# C(onet_major_x)[T.25]                    M    -0.2011   0.0190
# C(onet_major_x)[T.27]                    M    -0.0942   0.0207
# C(onet_major_x)[T.29]                    M     0.2166   0.0236
# C(onet_major_x)[T.31]                    M     0.1316   0.0829
# C(onet_major_x)[T.33]                    M    -0.1961   0.0657
# C(onet_major_x)[T.35]                    M    -0.3443   0.0597
# C(onet_major_x)[T.37]                    M    -0.1464   0.1474
# C(onet_major_x)[T.39]                    M    -0.2638   0.0548
# C(onet_major_x)[T.41]                    M     0.1601   0.0162
# C(onet_major_x)[T.43]                    M     0.1464   0.0197
# C(onet_major_x)[T.45]                    M    -0.0226   0.2517
# C(onet_major_x)[T.47]                    M    -0.0388   0.0987
# C(onet_major_x)[T.49]                    M    -0.1498   0.0735
# C(onet_major_x)[T.51]                    M     0.0447   0.0603
# C(onet_major_x)[T.53]                    M    -0.1019   0.0707
# C(nacis6_major_x)[T.21]                  M     0.1988   0.0578
# C(nacis6_major_x)[T.22]                  M     0.2163   0.0556
# C(nacis6_major_x)[T.23]                  M     0.1997   0.0283
# C(nacis6_major_x)[T.31]                  M     0.2798   0.0383
# C(nacis6_major_x)[T.32]                  M     0.1637   0.0320
# C(nacis6_major_x)[T.33]                  M     0.2138   0.0169
# C(nacis6_major_x)[T.42]                  M     0.2732   0.0264
# C(nacis6_major_x)[T.44]                  M    -0.1564   0.0245
# C(nacis6_major_x)[T.45]                  M    -0.1174   0.0292
# C(nacis6_major_x)[T.48]                  M     0.0858   0.0444
# C(nacis6_major_x)[T.49]                  M     0.0387   0.0728
# C(nacis6_major_x)[T.51]                  M     0.1818   0.0221
# C(nacis6_major_x)[T.52]                  M     0.1801   0.0155
# C(nacis6_major_x)[T.53]                  M     0.0099   0.0332
# C(nacis6_major_x)[T.54]                  M     0.2007   0.0128
# C(nacis6_major_x)[T.55]                  M     0.1439   0.0767
# C(nacis6_major_x)[T.56]                  M     0.0433   0.0297
# C(nacis6_major_x)[T.61]                  M    -0.2277   0.0134
# C(nacis6_major_x)[T.62]                  M    -0.0536   0.0169
# C(nacis6_major_x)[T.71]                  M    -0.1404   0.0388
# C(nacis6_major_x)[T.72]                  M    -0.0502   0.0331
# C(nacis6_major_x)[T.81]                  M    -0.0960   0.0310
# C(nacis6_major_x)[T.92]                  M    -0.1648   0.0335
# C(firm_obs_group_x)[T.Medium_N10-100]    M     0.0135   0.0092
# C(firm_obs_group_x)[T.Mega_N>300]        M     0.0516   0.0130
# C(firm_obs_group_x)[T.Sparse_N<10]       M    -0.0745   0.0080
# C(max_edu_name)[T.Doctorate]             M     1.2010   0.0234
# C(max_edu_name)[T.Master's Degree]       M     0.4053   0.0110
# C(generation)[T.Millennials]             M     0.1798   0.0057
# state_gdp_decile_x_scaled                M     0.0364   0.0051
# num_job_changes_scaled                   M     0.5935   0.0057
# log_wage_x_scaled                        M    -1.0004   0.0055
# firm_obs_group_re                        V    -3.3094   0.6480 0.037   0.010   0.134
# onet_group_re                            V    -4.2856   0.1657 0.014   0.010   0.019
# ====================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m1f.csv

# %% [markdown]
# ### Model 2F: Year 1 Firm Size + Occupation as REs

# %%
df = load_datatable(data_filename)
output_filename = f'../results/mglm_m2f.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(firm_obs_group_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled' +
'+ C(gender):C(move_1_1) + C(gender):C(move_1_2) + C(gender):C(move_2_1)'
)
random_formula = {
    'firm_obs_group_re': '0 + C(firm_obs_group_x)',
    'onet_group_re': '0 + C(onet_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 993.91 sec
#                              Binomial Mixed GLM Results
# ====================================================================================
#                                       Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ------------------------------------------------------------------------------------
# Intercept                                M    -1.0958   0.0051
# C(gender)[T.2]                           M    -0.0770   0.0072
# C(race)[T.2]                             M    -0.0718   0.0135
# C(race)[T.3]                             M     0.1274   0.0140
# C(race)[T.4]                             M     0.0238   0.0178
# C(move_1_1)[T.1]                         M     0.9692   0.0070
# C(move_1_2)[T.1]                         M     1.0005   0.0104
# C(move_2_1)[T.1]                         M     0.8560   0.0114
# C(onet_major_x)[T.13]                    M     0.4543   0.0118
# C(onet_major_x)[T.15]                    M     0.4131   0.0162
# C(onet_major_x)[T.17]                    M     0.4087   0.0192
# C(onet_major_x)[T.19]                    M    -0.0556   0.0234
# C(onet_major_x)[T.21]                    M    -0.1519   0.0304
# C(onet_major_x)[T.23]                    M    -0.0765   0.0343
# C(onet_major_x)[T.25]                    M    -0.2027   0.0190
# C(onet_major_x)[T.27]                    M    -0.0935   0.0207
# C(onet_major_x)[T.29]                    M     0.2147   0.0236
# C(onet_major_x)[T.31]                    M     0.1287   0.0828
# C(onet_major_x)[T.33]                    M    -0.1951   0.0658
# C(onet_major_x)[T.35]                    M    -0.3476   0.0597
# C(onet_major_x)[T.37]                    M    -0.1425   0.1475
# C(onet_major_x)[T.39]                    M    -0.2663   0.0547
# C(onet_major_x)[T.41]                    M     0.1591   0.0162
# C(onet_major_x)[T.43]                    M     0.1442   0.0197
# C(onet_major_x)[T.45]                    M    -0.0206   0.2518
# C(onet_major_x)[T.47]                    M    -0.0378   0.0989
# C(onet_major_x)[T.49]                    M    -0.1474   0.0737
# C(onet_major_x)[T.51]                    M     0.0461   0.0604
# C(onet_major_x)[T.53]                    M    -0.1019   0.0708
# C(nacis6_major_x)[T.21]                  M     0.1981   0.0579
# C(nacis6_major_x)[T.22]                  M     0.2195   0.0557
# C(nacis6_major_x)[T.23]                  M     0.2023   0.0283
# C(nacis6_major_x)[T.31]                  M     0.2824   0.0383
# C(nacis6_major_x)[T.32]                  M     0.1649   0.0321
# C(nacis6_major_x)[T.33]                  M     0.2165   0.0170
# C(nacis6_major_x)[T.42]                  M     0.2753   0.0264
# C(nacis6_major_x)[T.44]                  M    -0.1534   0.0244
# C(nacis6_major_x)[T.45]                  M    -0.1149   0.0292
# C(nacis6_major_x)[T.48]                  M     0.0865   0.0444
# C(nacis6_major_x)[T.49]                  M     0.0410   0.0728
# C(nacis6_major_x)[T.51]                  M     0.1839   0.0221
# C(nacis6_major_x)[T.52]                  M     0.1818   0.0155
# C(nacis6_major_x)[T.53]                  M     0.0116   0.0332
# C(nacis6_major_x)[T.54]                  M     0.2032   0.0128
# C(nacis6_major_x)[T.55]                  M     0.1466   0.0768
# C(nacis6_major_x)[T.56]                  M     0.0458   0.0297
# C(nacis6_major_x)[T.61]                  M    -0.2250   0.0134
# C(nacis6_major_x)[T.62]                  M    -0.0517   0.0168
# C(nacis6_major_x)[T.71]                  M    -0.1381   0.0388
# C(nacis6_major_x)[T.72]                  M    -0.0467   0.0331
# C(nacis6_major_x)[T.81]                  M    -0.0935   0.0310
# C(nacis6_major_x)[T.92]                  M    -0.1621   0.0335
# C(firm_obs_group_x)[T.Medium_N10-100]    M     0.0131   0.0092
# C(firm_obs_group_x)[T.Mega_N>300]        M     0.0519   0.0130
# C(firm_obs_group_x)[T.Sparse_N<10]       M    -0.0750   0.0080
# C(max_edu_name)[T.Doctorate]             M     1.2017   0.0234
# C(max_edu_name)[T.Master's Degree]       M     0.4054   0.0110
# C(generation)[T.Millennials]             M     0.1796   0.0057
# C(gender)[T.2]:C(move_1_1)[T.1]          M    -0.0573   0.0098
# C(gender)[T.2]:C(move_1_2)[T.1]          M    -0.1049   0.0148
# C(gender)[T.2]:C(move_2_1)[T.1]          M    -0.1015   0.0161
# state_gdp_decile_x_scaled                M     0.0365   0.0051
# num_job_changes_scaled                   M     0.5936   0.0057
# log_wage_x_scaled                        M    -1.0003   0.0055
# firm_obs_group_re                        V    -3.3093   0.6480 0.037   0.010   0.134
# onet_group_re                            V    -4.2855   0.1657 0.014   0.010   0.019
# ====================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m2f.csv

# %% [markdown]
# ### Model 3F: Year 1 Firm Size + Occupation as REs

# %%
df = load_datatable(data_filename)
output_filename = f'data/mglm_m3f.csv'
fixed_formula = (
'up_move ~ C(gender) + C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(firm_obs_group_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled' +
'+ C(race):C(move_1_1) + C(race):C(move_1_2) + C(race):C(move_2_1)'
)
random_formula = {
    'firm_obs_group_re': '0 + C(firm_obs_group_x)',
    'onet_group_re': '0 + C(onet_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 1039.41 sec
#                              Binomial Mixed GLM Results
# ====================================================================================
#                                       Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ------------------------------------------------------------------------------------
# Intercept                                M    -1.0669   0.0051
# C(gender)[T.2]                           M    -0.1518   0.0072
# C(race)[T.2]                             M    -0.0652   0.0136
# C(race)[T.3]                             M     0.1699   0.0139
# C(race)[T.4]                             M     0.0632   0.0178
# C(move_1_1)[T.1]                         M     0.9446   0.0070
# C(move_1_2)[T.1]                         M     0.9647   0.0104
# C(move_2_1)[T.1]                         M     0.8274   0.0114
# C(onet_major_x)[T.13]                    M     0.4560   0.0118
# C(onet_major_x)[T.15]                    M     0.4135   0.0161
# C(onet_major_x)[T.17]                    M     0.4074   0.0191
# C(onet_major_x)[T.19]                    M    -0.0560   0.0234
# C(onet_major_x)[T.21]                    M    -0.1493   0.0305
# C(onet_major_x)[T.23]                    M    -0.0741   0.0343
# C(onet_major_x)[T.25]                    M    -0.2005   0.0190
# C(onet_major_x)[T.27]                    M    -0.0939   0.0207
# C(onet_major_x)[T.29]                    M     0.2166   0.0236
# C(onet_major_x)[T.31]                    M     0.1321   0.0829
# C(onet_major_x)[T.33]                    M    -0.1963   0.0657
# C(onet_major_x)[T.35]                    M    -0.3437   0.0597
# C(onet_major_x)[T.37]                    M    -0.1460   0.1474
# C(onet_major_x)[T.39]                    M    -0.2633   0.0548
# C(onet_major_x)[T.41]                    M     0.1602   0.0162
# C(onet_major_x)[T.43]                    M     0.1464   0.0197
# C(onet_major_x)[T.45]                    M    -0.0199   0.2517
# C(onet_major_x)[T.47]                    M    -0.0383   0.0987
# C(onet_major_x)[T.49]                    M    -0.1491   0.0735
# C(onet_major_x)[T.51]                    M     0.0445   0.0603
# C(onet_major_x)[T.53]                    M    -0.1022   0.0707
# C(nacis6_major_x)[T.21]                  M     0.1982   0.0578
# C(nacis6_major_x)[T.22]                  M     0.2155   0.0556
# C(nacis6_major_x)[T.23]                  M     0.1987   0.0283
# C(nacis6_major_x)[T.31]                  M     0.2789   0.0383
# C(nacis6_major_x)[T.32]                  M     0.1631   0.0320
# C(nacis6_major_x)[T.33]                  M     0.2126   0.0169
# C(nacis6_major_x)[T.42]                  M     0.2717   0.0264
# C(nacis6_major_x)[T.44]                  M    -0.1577   0.0245
# C(nacis6_major_x)[T.45]                  M    -0.1189   0.0292
# C(nacis6_major_x)[T.48]                  M     0.0842   0.0444
# C(nacis6_major_x)[T.49]                  M     0.0377   0.0728
# C(nacis6_major_x)[T.51]                  M     0.1805   0.0221
# C(nacis6_major_x)[T.52]                  M     0.1791   0.0155
# C(nacis6_major_x)[T.53]                  M     0.0086   0.0332
# C(nacis6_major_x)[T.54]                  M     0.1992   0.0128
# C(nacis6_major_x)[T.55]                  M     0.1435   0.0767
# C(nacis6_major_x)[T.56]                  M     0.0421   0.0297
# C(nacis6_major_x)[T.61]                  M    -0.2293   0.0134
# C(nacis6_major_x)[T.62]                  M    -0.0548   0.0169
# C(nacis6_major_x)[T.71]                  M    -0.1419   0.0388
# C(nacis6_major_x)[T.72]                  M    -0.0513   0.0331
# C(nacis6_major_x)[T.81]                  M    -0.0973   0.0310
# C(nacis6_major_x)[T.92]                  M    -0.1663   0.0335
# C(firm_obs_group_x)[T.Medium_N10-100]    M     0.0137   0.0092
# C(firm_obs_group_x)[T.Mega_N>300]        M     0.0515   0.0130
# C(firm_obs_group_x)[T.Sparse_N<10]       M    -0.0742   0.0080
# C(max_edu_name)[T.Doctorate]             M     1.2005   0.0234
# C(max_edu_name)[T.Master's Degree]       M     0.4050   0.0110
# C(generation)[T.Millennials]             M     0.1794   0.0057
# C(race)[T.2]:C(move_1_1)[T.1]            M    -0.0026   0.0185
# C(race)[T.3]:C(move_1_1)[T.1]            M    -0.0152   0.0192
# C(race)[T.4]:C(move_1_1)[T.1]            M    -0.0105   0.0247
# C(race)[T.2]:C(move_1_2)[T.1]            M     0.0164   0.0284
# C(race)[T.3]:C(move_1_2)[T.1]            M    -0.0991   0.0299
# C(race)[T.4]:C(move_1_2)[T.1]            M    -0.0713   0.0362
# C(race)[T.2]:C(move_2_1)[T.1]            M    -0.0453   0.0310
# C(race)[T.3]:C(move_2_1)[T.1]            M    -0.0616   0.0296
# C(race)[T.4]:C(move_2_1)[T.1]            M    -0.0862   0.0401
# state_gdp_decile_x_scaled                M     0.0364   0.0051
# num_job_changes_scaled                   M     0.5933   0.0057
# log_wage_x_scaled                        M    -1.0006   0.0055
# firm_obs_group_re                        V    -3.3094   0.6480 0.037   0.010   0.134
# onet_group_re                            V    -4.2855   0.1657 0.014   0.010   0.019
# ====================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m3f.csv

# %% [markdown]
# ### Model 4F: Year 1 Firm Size + Occupation as REs

# %%
df = load_datatable(data_filename)
df = df.query("gender==1")
output_filename = f'../results/mglm_m4f-m.csv'
fixed_formula = (
'up_move ~ C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(firm_obs_group_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled' +
'+ C(race):C(move_1_1) + C(race):C(move_1_2) + C(race):C(move_2_1)'
)
random_formula = {
    'firm_obs_group_re': '0 + C(firm_obs_group_x)',
    'onet_group_re': '0 + C(onet_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 385.27 sec
#                              Binomial Mixed GLM Results
# ====================================================================================
#                                       Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ------------------------------------------------------------------------------------
# Intercept                                M    -1.2127   0.0071
# C(race)[T.2]                             M    -0.0955   0.0205
# C(race)[T.3]                             M     0.0898   0.0196
# C(race)[T.4]                             M     0.0343   0.0253
# C(move_1_1)[T.1]                         M     0.9343   0.0101
# C(move_1_2)[T.1]                         M     0.9819   0.0146
# C(move_2_1)[T.1]                         M     0.8564   0.0162
# C(onet_major_x)[T.13]                    M     0.5231   0.0168
# C(onet_major_x)[T.15]                    M     0.4898   0.0191
# C(onet_major_x)[T.17]                    M     0.4690   0.0219
# C(onet_major_x)[T.19]                    M     0.0146   0.0327
# C(onet_major_x)[T.21]                    M    -0.1862   0.0563
# C(onet_major_x)[T.23]                    M    -0.0440   0.0501
# C(onet_major_x)[T.25]                    M    -0.0561   0.0305
# C(onet_major_x)[T.27]                    M    -0.1879   0.0318
# C(onet_major_x)[T.29]                    M     0.1194   0.0456
# C(onet_major_x)[T.31]                    M     0.2087   0.1616
# C(onet_major_x)[T.33]                    M    -0.1392   0.0798
# C(onet_major_x)[T.35]                    M    -0.3761   0.0902
# C(onet_major_x)[T.37]                    M    -0.0733   0.1826
# C(onet_major_x)[T.39]                    M    -0.2399   0.0889
# C(onet_major_x)[T.41]                    M     0.2450   0.0221
# C(onet_major_x)[T.43]                    M     0.1476   0.0336
# C(onet_major_x)[T.45]                    M    -0.2140   0.3332
# C(onet_major_x)[T.47]                    M     0.0537   0.1083
# C(onet_major_x)[T.49]                    M    -0.1283   0.0803
# C(onet_major_x)[T.51]                    M     0.1339   0.0723
# C(onet_major_x)[T.53]                    M    -0.0066   0.0836
# C(nacis6_major_x)[T.21]                  M     0.2190   0.0693
# C(nacis6_major_x)[T.22]                  M     0.1914   0.0711
# C(nacis6_major_x)[T.23]                  M     0.1270   0.0355
# C(nacis6_major_x)[T.31]                  M     0.2010   0.0533
# C(nacis6_major_x)[T.32]                  M     0.1338   0.0433
# C(nacis6_major_x)[T.33]                  M     0.1126   0.0207
# C(nacis6_major_x)[T.42]                  M     0.2085   0.0350
# C(nacis6_major_x)[T.44]                  M    -0.1887   0.0365
# C(nacis6_major_x)[T.45]                  M    -0.0877   0.0446
# C(nacis6_major_x)[T.48]                  M     0.0658   0.0569
# C(nacis6_major_x)[T.49]                  M    -0.1005   0.0959
# C(nacis6_major_x)[T.51]                  M     0.1267   0.0296
# C(nacis6_major_x)[T.52]                  M     0.1298   0.0208
# C(nacis6_major_x)[T.53]                  M    -0.0254   0.0457
# C(nacis6_major_x)[T.54]                  M     0.1127   0.0176
# C(nacis6_major_x)[T.55]                  M     0.0593   0.1033
# C(nacis6_major_x)[T.56]                  M    -0.0245   0.0423
# C(nacis6_major_x)[T.61]                  M    -0.3463   0.0202
# C(nacis6_major_x)[T.62]                  M    -0.1214   0.0313
# C(nacis6_major_x)[T.71]                  M    -0.2520   0.0571
# C(nacis6_major_x)[T.72]                  M    -0.0921   0.0490
# C(nacis6_major_x)[T.81]                  M    -0.0953   0.0494
# C(nacis6_major_x)[T.92]                  M    -0.2199   0.0467
# C(firm_obs_group_x)[T.Medium_N10-100]    M     0.0208   0.0131
# C(firm_obs_group_x)[T.Mega_N>300]        M     0.0704   0.0173
# C(firm_obs_group_x)[T.Sparse_N<10]       M    -0.0529   0.0114
# C(max_edu_name)[T.Doctorate]             M     1.1791   0.0321
# C(max_edu_name)[T.Master's Degree]       M     0.4017   0.0160
# C(generation)[T.Millennials]             M     0.1891   0.0081
# C(race)[T.2]:C(move_1_1)[T.1]            M     0.0524   0.0284
# C(race)[T.3]:C(move_1_1)[T.1]            M     0.0719   0.0278
# C(race)[T.4]:C(move_1_1)[T.1]            M    -0.0076   0.0355
# C(race)[T.2]:C(move_1_2)[T.1]            M     0.0973   0.0435
# C(race)[T.3]:C(move_1_2)[T.1]            M    -0.1135   0.0424
# C(race)[T.4]:C(move_1_2)[T.1]            M    -0.0885   0.0514
# C(race)[T.2]:C(move_2_1)[T.1]            M    -0.0500   0.0469
# C(race)[T.3]:C(move_2_1)[T.1]            M    -0.0216   0.0425
# C(race)[T.4]:C(move_2_1)[T.1]            M    -0.0498   0.0583
# state_gdp_decile_x_scaled                M     0.0235   0.0071
# num_job_changes_scaled                   M     0.6058   0.0081
# log_wage_x_scaled                        M    -0.9622   0.0078
# firm_obs_group_re                        V    -3.1593   0.6107 0.042   0.013   0.144
# onet_group_re                            V    -3.9835   0.1643 0.019   0.013   0.026
# ====================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m4f-m.csv

# %%
df = load_datatable(data_filename)
df = df.query("gender==2")
output_filename = f'data/mglm_m4f-f.csv'
fixed_formula = (
'up_move ~ C(race) + C(move_1_1) + C(move_1_2) + C(move_2_1)' +
'+ C(onet_major_x) + C(nacis6_major_x) + C(firm_obs_group_x) + C(max_edu_name) + C(generation)' +
'+ state_gdp_decile_x_scaled + num_job_changes_scaled + log_wage_x_scaled' +
'+ C(race):C(move_1_1) + C(race):C(move_1_2) + C(race):C(move_2_1)'
)
random_formula = {
    'firm_obs_group_re': '0 + C(firm_obs_group_x)',
    'onet_group_re': '0 + C(onet_major_x)'
}
run_mglm(fixed_formula, random_formula, output_filename)
# Out:
# Done in 371.29 sec
#                              Binomial Mixed GLM Results
# ====================================================================================
#                                       Type Post. Mean Post. SD   SD  SD (LB) SD (UB)
# ------------------------------------------------------------------------------------
# Intercept                                M    -1.0501   0.0072
# C(race)[T.2]                             M    -0.0504   0.0181
# C(race)[T.3]                             M     0.2672   0.0197
# C(race)[T.4]                             M     0.0953   0.0250
# C(move_1_1)[T.1]                         M     0.9558   0.0098
# C(move_1_2)[T.1]                         M     0.9445   0.0148
# C(move_2_1)[T.1]                         M     0.7925   0.0161
# C(onet_major_x)[T.13]                    M     0.3818   0.0167
# C(onet_major_x)[T.15]                    M     0.2843   0.0302
# C(onet_major_x)[T.17]                    M     0.3112   0.0401
# C(onet_major_x)[T.19]                    M    -0.1322   0.0336
# C(onet_major_x)[T.21]                    M    -0.1763   0.0362
# C(onet_major_x)[T.23]                    M    -0.1240   0.0471
# C(onet_major_x)[T.25]                    M    -0.3227   0.0244
# C(onet_major_x)[T.27]                    M    -0.0360   0.0273
# C(onet_major_x)[T.29]                    M     0.2237   0.0276
# C(onet_major_x)[T.31]                    M     0.0542   0.0965
# C(onet_major_x)[T.33]                    M    -0.3007   0.1164
# C(onet_major_x)[T.35]                    M    -0.3561   0.0796
# C(onet_major_x)[T.37]                    M    -0.2238   0.2495
# C(onet_major_x)[T.39]                    M    -0.3198   0.0695
# C(onet_major_x)[T.41]                    M     0.0541   0.0239
# C(onet_major_x)[T.43]                    M     0.1065   0.0243
# C(onet_major_x)[T.45]                    M     0.2386   0.3875
# C(onet_major_x)[T.47]                    M    -0.3954   0.2457
# C(onet_major_x)[T.49]                    M    -0.1009   0.1859
# C(onet_major_x)[T.51]                    M    -0.1102   0.1094
# C(onet_major_x)[T.53]                    M    -0.3089   0.1332
# C(nacis6_major_x)[T.21]                  M     0.0461   0.1051
# C(nacis6_major_x)[T.22]                  M     0.2013   0.0897
# C(nacis6_major_x)[T.23]                  M     0.2617   0.0472
# C(nacis6_major_x)[T.31]                  M     0.3539   0.0551
# C(nacis6_major_x)[T.32]                  M     0.1728   0.0478
# C(nacis6_major_x)[T.33]                  M     0.3365   0.0295
# C(nacis6_major_x)[T.42]                  M     0.3194   0.0403
# C(nacis6_major_x)[T.44]                  M    -0.1303   0.0329
# C(nacis6_major_x)[T.45]                  M    -0.1312   0.0386
# C(nacis6_major_x)[T.48]                  M     0.0622   0.0713
# C(nacis6_major_x)[T.49]                  M     0.1958   0.1121
# C(nacis6_major_x)[T.51]                  M     0.2234   0.0332
# C(nacis6_major_x)[T.52]                  M     0.2105   0.0234
# C(nacis6_major_x)[T.53]                  M     0.0268   0.0485
# C(nacis6_major_x)[T.54]                  M     0.2759   0.0188
# C(nacis6_major_x)[T.55]                  M     0.2119   0.1148
# C(nacis6_major_x)[T.56]                  M     0.1010   0.0417
# C(nacis6_major_x)[T.61]                  M    -0.1351   0.0179
# C(nacis6_major_x)[T.62]                  M    -0.0058   0.0200
# C(nacis6_major_x)[T.71]                  M    -0.0267   0.0530
# C(nacis6_major_x)[T.72]                  M    -0.0133   0.0450
# C(nacis6_major_x)[T.81]                  M    -0.0856   0.0399
# C(nacis6_major_x)[T.92]                  M    -0.1216   0.0481
# C(firm_obs_group_x)[T.Medium_N10-100]    M     0.0041   0.0129
# C(firm_obs_group_x)[T.Mega_N>300]        M     0.0343   0.0198
# C(firm_obs_group_x)[T.Sparse_N<10]       M    -0.0994   0.0111
# C(max_edu_name)[T.Doctorate]             M     1.2514   0.0345
# C(max_edu_name)[T.Master's Degree]       M     0.4130   0.0151
# C(generation)[T.Millennials]             M     0.1689   0.0081
# C(race)[T.2]:C(move_1_1)[T.1]            M    -0.0354   0.0243
# C(race)[T.3]:C(move_1_1)[T.1]            M    -0.1118   0.0267
# C(race)[T.4]:C(move_1_1)[T.1]            M    -0.0197   0.0343
# C(race)[T.2]:C(move_1_2)[T.1]            M    -0.0226   0.0374
# C(race)[T.3]:C(move_1_2)[T.1]            M    -0.0767   0.0423
# C(race)[T.4]:C(move_1_2)[T.1]            M    -0.0496   0.0510
# C(race)[T.2]:C(move_2_1)[T.1]            M    -0.0232   0.0414
# C(race)[T.3]:C(move_2_1)[T.1]            M    -0.0987   0.0413
# C(race)[T.4]:C(move_2_1)[T.1]            M    -0.1187   0.0553
# state_gdp_decile_x_scaled                M     0.0511   0.0072
# num_job_changes_scaled                   M     0.5804   0.0081
# log_wage_x_scaled                        M    -1.0337   0.0078
# firm_obs_group_re                        V    -3.1321   0.6046 0.044   0.013   0.146
# onet_group_re                            V    -3.9824   0.1643 0.019   0.013   0.026
# ====================================================================================
# Parameter types are mean structure (M) and variance structure (V)
# Variance parameters are modeled as log standard deviations
# Exported results table to data/mglm_m4f-f.csv
